# %% [markdown]
# **Retrieval and Generation**

# %%
# Importing the Dependencies

import os

from langchain_chroma import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain_groq import ChatGroq

# %%
from dotenv import load_dotenv
load_dotenv()

assert os.getenv("GROQ_API_KEY"), "GROQ_API_KEY not found"

# %%
#loading the embedding model - default model

embedding = HuggingFaceEmbeddings()
# Out:
# C:\Users\addys\anaconda3\envs\genai-env\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
vector_db_path = "vector_db"
collection_name = "document_collection"

# %%
# Initialize groq llm 

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.0
)

# %%
# Load vector database

vector_store = Chroma(
    persist_directory="vector_db",
    embedding_function=embedding
)

# %%
# Create retriever

retriever = vector_store.as_retriever()

# %%
# Create RAG chain

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever
)

# %%
# Ask question

query = "Types of Ecosystems"
result = qa_chain.invoke({"query": query})

#  Print answer

print(result["result"])
# Out:
# There are several types of ecosystems, which can be classified based on various factors such as location, climate, and vegetation. Here are some of the main types of ecosystems:
#
# 1. **Terrestrial Ecosystems**:
# 	* **Deserts**: Hot and dry ecosystems with limited vegetation, such as the Sahara Desert.
# 	* **Grasslands**: Temperate ecosystems with grasses and few trees, such as the Prairies in North America.
# 	* **Tundras**: Cold and treeless ecosystems found in Arctic and sub-Arctic regions.
# 	* **Forests**: Ecosystems dominated by trees, such as tropical rainforests, temperate forests, and boreal forests.
# 2. **Freshwater Ecosystems**:
# 	* **Rivers**: Ecosystems found in flowing water, such as the Amazon River.
# 	* **Lakes**: Ecosystems found in standing water, such as the Great Lakes.
# 	* **Wetlands**: Ecosystems found in areas with saturated soil, such as marshes and swamps.
# 3. **Marine Ecosystems**:
# 	* **Coral Reefs**: Ecosystems found in tropical oceans, characterized by coral formations and diverse marine life.
# 	* **Estuaries**: Ecosystems found where freshwater rivers meet the ocean, such as the Chesapeake Bay.
# 	* **Open Ocean**: Ecosystems found in the open sea, characterized by diverse marine life and ocean currents.
# 4. **Atmospheric Ecosystems**:
# 	* **Atmosphere**: The global ecosystem that surrounds the Earth, including the air and gases that make up the atmosphere.
# 5. **Human-Made Ecosystems**:
# 	* **Urban Ecosystems**: Ecosystems found in cities and towns, characterized by human activity and infrastructure.
# 	* **Agricultural Ecosystems**: Ecosystems found in agricultural areas, such as farms and plantations.
#
# These are just a few examples of the many types of ecosystems that exist on Earth. Each ecosystem has its unique characteristics, and they all play important roles in supporting life on our planet.
